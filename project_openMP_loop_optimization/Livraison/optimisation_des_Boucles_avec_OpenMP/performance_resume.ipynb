# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('performance_report.csv')

data = data.drop(columns=['thread_times'], errors='ignore')
data = data.drop(columns=['start_date'], errors='ignore')
data = data.drop(columns=['end_date'], errors='ignore')

parallel_data = data[data['program_name'].str.startswith('parallel')]
sequential_data = data[data['program_name'].str.startswith('sequential')]

print("Tableau des performances :")
print(data)

fig, ax = plt.subplots(figsize=(10, len(data) * 0.5))

ax.axis('tight')
ax.axis('off')

table = ax.table(cellText=data.values, colLabels=data.columns, cellLoc='center', loc='center')

table.auto_set_font_size(False)
table.set_fontsize(10)

plt.savefig('performance_report_table.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# Tableau des performances :
#                               program_name  threads_count  execution_time  \
# 0                   sequential_simple_loop              1       17.058041
# 1                sequential_loop_unrolling              1       14.961129
# 2                   sequential_loop_fusion              1       15.442099
# 3        sequential_combined_optimizations              1       14.756591
# 4              parallel_simple_loop_openmp              2       23.132451
# 5              parallel_simple_loop_openmp              4       13.662971
# 6              parallel_simple_loop_openmp              6       11.613298
# 7              parallel_simple_loop_openmp              8       11.587700
# 8           parallel_loop_unrolling_openmp              2       12.865141
# 9           parallel_loop_unrolling_openmp              4        6.662790
# 10          parallel_loop_unrolling_openmp              6        4.983059
# 11          parallel_loop_unrolling_openmp              8        4.632218
# 12             parallel_loop_fusion_openmp              2       16.485042
# 13             parallel_loop_fusion_openmp              4        8.952679
# 14             parallel_loop_fusion_openmp              6        6.974568
# 15             parallel_loop_fusion_openmp              8        6.870879
# 16  parallel_combined_optimizations_openmp              2       11.017359
# 17  parallel_combined_optimizations_openmp              4        5.582242
# 18  parallel_combined_optimizations_openmp              6        4.561367
# 19  parallel_combined_optimizations_openmp              8        4.915408
#
#     speedup  efficiency   work  overhead
# 0       NaN         NaN    NaN       NaN
# 1       NaN         NaN    NaN       NaN
# 2       NaN         NaN    NaN       NaN
# 3       NaN         NaN    NaN       NaN
# 4      0.74        0.37  46.26     14.60
# 5      1.25        0.31  54.65      9.40
# 6      1.47        0.24  69.68      8.77
# 7      1.47        0.18  92.70      9.46
# 8      1.16        0.58  25.73      5.39
# 9      2.25        0.56  26.65      2.92
# 10     3.00        0.50  29.90      2.49
# 11     3.23        0.40  37.06      2.76
# 12     0.94        0.47  32.97      8.77
# 13     1.72        0.43  35.81      5.09
# 14     2.21        0.37  41.85      4.40
# 15     2.25        0.28  54.97      4.94
# 16     1.34        0.67  22.03      3.64
# 17     2.64        0.66  22.33      1.89
# 18     3.24        0.54  27.37      2.10
# 19     3.00        0.38  39.32      3.08
